# %%
# This Jupyter Notebook accesses Breweries data from https://api.openbrewerydb.org/breweries

import pandas as pd
import numpy as np
import requests
import json
import gmaps
import ipywidgets as widgets
from api_keys import rapidapi_key
from api_keys import g_key
gmaps.configure(api_key=g_key)

# %%
search_state = input("Enter State to search for breweries: ")
search_city = input("Enter City to search for breweries: ")
search_type_options = [' ', 'micro', 'regional', 'brewpub', 'large', 'planning', 'bar', 'contract', 'proprietor']
w1 = widgets.Dropdown(
    options=search_type_options,
    value=' ',
    description='Type:',
    disabled=False,
)
display(w1)
# Out:
# Enter State to search for breweries: texas
# Enter City to search for breweries: austin
# Dropdown(description='Type:', options=(' ', 'micro', 'regional', 'brewpub', 'large', 'planning', 'bar', 'contr…

# %%
base_url2 = "https://api.openbrewerydb.org/breweries?"
query_url2 = base_url2 + "by_city=" + search_city + "&by_state=" + search_state + "&by_type=" + w1.value +"&per_page=50" + "&pages=1"
b_response = requests.get(query_url2)
b_json = b_response.json()
#print(json.dumps(b_json, indent=4, sort_keys=True))

# %%
# Reset variabes
count = 0
name = []
type = []
address = []
phone = []
city = []
state = []
zip = []
country = []
website =[]
lat = []
lng = []

# %%
for block in b_json:
    #print(block)
    count +=1
    name.append(block['name'])
    type.append(block['brewery_type'])
    address.append(block['street'])
    phone.append(block['phone'])
    city.append(block['city'])
    state.append(block['state'])
    zip.append(block['postal_code'])
    country.append(block['country'])
    website.append(block['website_url'])
    lat.append(block['latitude'])
    lng.append(block['longitude'])

# create a data frame from cities and all the response parameters
breweries_bycity_dict = {
    "Name": name,
    "Type": type,
    "Address": address,
    "Phone": phone,
    "City": city,
    "State": state,
    "ZIP": zip,
    "Country": country,
    "Website": website,
    "Lat": lat,
    "Lng": lng
}
breweries_bycity_df = pd.DataFrame(breweries_bycity_dict)
breweries_bycity_df['Lat'] = pd.to_numeric(breweries_bycity_df['Lat'], errors='coerce')
breweries_bycity_df['Lng'] = pd.to_numeric(breweries_bycity_df['Lng'], errors='coerce')
breweries_bycity_df
# Out:
#                                   Name   Type  \
# 0                  Jester King Brewery  micro
# 1          Oasis Texas Brewing Company  micro
# 2                     (512) Brewing Co  micro
# 3          4th Tap Brewing Cooperative  micro
# 4               Adelbert's Brewery LLC  micro
# 5                        Celis Brewery  micro
# 6               Circle Brewing Company  micro
# 7        Draught House Pub and Brewery  micro
# 8           Flying Man Brewing Company  micro
# 9                      Hi Sign Brewing  micro
# 10                Hops & Grain Brewing  micro
# 11  Friends and Allies Brewing Company  micro
# 12                    Infamous Brewing  micro
# 13          Last Stand Brewing Company  micro
# 14                         Orf Brewing  micro
# 15                 Oskar Blues Brewery  micro
# 16              Skull Mechanix Brewing  micro
# 17                South Austin Brewery  micro
# 18     Southern Heights Brewing Co LLC  micro
# 19                Strange Land Brewery  micro
# 20           Thirsty Planet Brewing Co  micro
# 21               Uncle Billy's Brewery  micro
# 22                   Zilker Brewing Co  micro
# 23                    Blue Owl Brewing  micro
# 24                   Frontyard Brewing  micro
# 25            St. Elmo Brewing Company  micro
#
#                                Address       Phone    City  State         ZIP  \
# 0                    13187 Fitzhugh Rd  5125375100  Austin  Texas  78736-6510
# 1            6548 Comanche Trl Ste 301  5122849407  Austin  Texas  78732-1210
# 2                407 Radam Ln Ste F200  5129211545  Austin  Texas  78745-1197
# 3                    10615 Metric Blvd  5129089817  Austin  Texas  78758-4520
# 4              2314 Rutland Dr Ste 100  5126621462  Austin  Texas  78758-5273
# 5                    10001 Metic Blvd.  5125242377  Austin  Texas       78758
# 6               2340 W Braker Ln Ste B  5128147599  Austin  Texas  78758-4542
# 7            4112 Medical Pkwy Ste 100  5124526258  Austin  Texas  78756-3715
# 8            2400 Patterson Industrial  5129104099  Austin  Texas       78660
# 9          1201 Old Bastrop Hwy Bldg A  5123825264  Austin  Texas  78742-2600
# 10               507 Calles St Ste 101  5129142467  Austin  Texas  78702-3954
# 11           979 Springdale Rd Ste 124              Austin  Texas  78702-3753
# 12                     4602 Weletka Dr  5124878786  Austin  Texas  78734-1829
# 13               12345 Pauls Valley Rd  5123733629  Austin  Texas  78737-9615
# 14              4700 Burleson Rd Ste F  5124285217  Austin  Texas  78744-1230
# 15             10420 Metric Blvd # 150  5122437054  Austin  Texas  78758-4939
# 16         1005 East St Elmo Rd Bldg 2  7373001002  Austin  Texas       78745
# 17       5701 W Slaughter Ln Bldg A130  5123542337  Austin  Texas  78749-6532
# 18     6014 Techni Center Dr Ste 2-101  5126506901  Austin  Texas  78721-2349
# 19                  5904 Bee Cave Road  5122762295  Austin  Texas       78746
# 20                 8201 S Congress Ave  5128260948  Austin  Texas  78745-7305
# 21              1530 Barton Springs Rd  5124760100  Austin  Texas  78704-1013
# 22                       1701 E 6th St  5127654946  Austin  Texas  78702-2701
# 23      2400 E Cesar Chavez St Ste 300  5125931262  Austin  Texas  78702-4638
# 24  1607 Cuernavaca Dr North Unit #202  8503227498  Austin  Texas       78733
# 25                 440 E Saint Elmo Rd  7373001965  Austin  Texas  78745-1281
#
#           Country                                Website        Lat        Lng
# 0   United States       http://www.jesterkingbrewery.com  30.254726 -98.082469
# 1   United States                   http://www.otxbc.com  30.043267 -98.151206
# 2   United States              http://www.512brewing.com        NaN        NaN
# 3   United States                                         30.385202 -97.711891
# 4   United States           http://www.adelbertsbeer.com  30.382629 -97.720159
# 5   United States              http://www.celisbeers.com        NaN        NaN
# 6   United States           http://www.circlebrewing.com        NaN        NaN
# 7   United States            http://www.draughthouse.com  30.311071 -97.742861
# 8   United States        http://www.flyingmanbrewing.com        NaN        NaN
# 9   United States           http://www.hisignbrewing.com        NaN        NaN
# 10  United States            http://www.hopsandgrain.com        NaN        NaN
# 11  United States       http://www.friendsandallies.beer  30.262862 -97.696185
# 12  United States         http://www.infamousbrewing.com        NaN        NaN
# 13  United States        http://www.laststandbrewing.com        NaN        NaN
# 14  United States              http://www.orfbrewing.com        NaN        NaN
# 15  United States                                         30.383929 -97.714702
# 16  United States           http://www.skullmechanix.com        NaN        NaN
# 17  United States      http://www.southaustinbrewery.com        NaN        NaN
# 18  United States  http://www.southernheightsbrewing.com        NaN        NaN
# 19  United States      http://www.strangelandbrewery.com        NaN        NaN
# 20  United States           http://www.thirstyplanet.net  30.252166 -97.748714
# 21  United States             http://www.unclebillys.com  30.262109 -97.761269
# 22  United States              http://www.zilkerbeer.com  30.262151 -97.724575
# 23  United States          http://www.blueowlbrewing.com        NaN        NaN
# 24  United States        http://www.frontyardbrewing.com        NaN        NaN
# 25  United States           http://www.stelmobrewing.com  30.217432 -97.761175

# %%
# DataFrame has breweries with incomplete Lat and Lng data

nan_rows = breweries_bycity_df[breweries_bycity_df['Lat'].isnull()]
index_nan_rows = list(nan_rows.index)
print(index_nan_rows)
for index, row in breweries_bycity_df.iterrows():
    if index in index_nan_rows:
        target_search = row['Address']
        print(index, row['Name'], target_search)
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                    'address={0}&key={1}').format(target_search, g_key)

        # Run a request to endpoint and convert result to json
        geo_data = requests.get(target_url).json()
        # Print the json
        print("ADDRESS SEARCH..." + json.dumps(geo_data, indent=4, sort_keys=True))
        if geo_data['status'] == "OK":
            print(geo_data['results'][0]['geometry']['location']['lat'])
            print(geo_data['results'][0]['geometry']['location']['lng'])
            breweries_bycity_df.at[index,'Lat'] = geo_data['results'][0]['geometry']['location']['lat']
            breweries_bycity_df.at[index,'Lng'] = geo_data['results'][0]['geometry']['location']['lng']
        else:
            target_search = f"{row['Name']},{row['City']},{row['State']}"
            print("CITY SEARCH..." + str(index) + row['Name'] + target_search)
            target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                    'address={0}&key={1}').format(target_search, g_key)           
            # Run a request to endpoint and convert result to json
            geo_data = requests.get(target_url).json()
            # Print the json
            print(json.dumps(geo_data, indent=4, sort_keys=True))
            if geo_data['status'] != "INVALID_REQUEST":
                print(geo_data['results'][0]['geometry']['location']['lat'])
                print(geo_data['results'][0]['geometry']['location']['lng'])
                breweries_bycity_df.at[index,'Lat'] = geo_data['results'][0]['geometry']['location']['lat']
                breweries_bycity_df.at[index,'Lng'] = geo_data['results'][0]['geometry']['location']['lng']
# Out:
# [2, 5, 6, 8, 9, 10, 12, 13, 14, 16, 17, 18, 19, 23, 24]
# 2 (512) Brewing Co 407 Radam Ln Ste F200
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "F200",
#                     "short_name": "F200",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "407",
#                     "short_name": "407",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Radam Lane",
#                     "short_name": "Radam Ln",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "South Austin",
#                     "short_name": "South Austin",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78745",
#                     "short_name": "78745",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "407 Radam Ln F200, Austin, TX 78745, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2237538,
#                         "lng": -97.76918599999999
#                     },
#                     "southwest": {
#                         "lat": 30.2216003,
#                         "lng": -97.7710397
#                     }
#                 },
#                 "location": {
#                     "lat": 30.222487,
#                     "lng": -97.77002449999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2240260302915,
#                         "lng": -97.76876386970848
#                     },
#                     "southwest": {
#                         "lat": 30.2213280697085,
#                         "lng": -97.7714618302915
#                     }
#                 }
#             },
#             "place_id": "Eig0MDcgUmFkYW0gTG4gRjIwMCwgQXVzdGluLCBUWCA3ODc0NSwgVVNBIiAaHgoWChQKEgnLPtLYu7REhhHNJLpby68XgxIERjIwMA",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.222487
# -97.77002449999999
# 5 Celis Brewery 10001 Metic Blvd.
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "10001",
#                     "short_name": "10001",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Metric Boulevard",
#                     "short_name": "Metric Blvd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "North Austin Civic Association",
#                     "short_name": "North Austin Civic Association",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78758",
#                     "short_name": "78758",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "5299",
#                     "short_name": "5299",
#                     "types": [
#                         "postal_code_suffix"
#                     ]
#                 }
#             ],
#             "formatted_address": "10001 Metric Blvd, Austin, TX 78758, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.3799828,
#                         "lng": -97.71570919999999
#                     },
#                     "southwest": {
#                         "lat": 30.3794728,
#                         "lng": -97.7162615
#                     }
#                 },
#                 "location": {
#                     "lat": 30.3798084,
#                     "lng": -97.7159575
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.3810767802915,
#                         "lng": -97.71463636970849
#                     },
#                     "southwest": {
#                         "lat": 30.37837881970851,
#                         "lng": -97.71733433029151
#                     }
#                 }
#             },
#             "place_id": "ChIJoYH7ku3LRIYRLNs6JRrsLVY",
#             "types": [
#                 "premise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.3798084
# -97.7159575
# 6 Circle Brewing Company 2340 W Braker Ln Ste B
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ste B",
#                     "short_name": "Ste B",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "2340",
#                     "short_name": "2340",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "West Braker Lane",
#                     "short_name": "W Braker Ln",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "North Burnet",
#                     "short_name": "North Burnet",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78758",
#                     "short_name": "78758",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "4542",
#                     "short_name": "4542",
#                     "types": [
#                         "postal_code_suffix"
#                     ]
#                 }
#             ],
#             "formatted_address": "2340 W Braker Ln Ste B, Austin, TX 78758, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.3915541,
#                         "lng": -97.7150759
#                     },
#                     "southwest": {
#                         "lat": 30.3906997,
#                         "lng": -97.7156713
#                     }
#                 },
#                 "location": {
#                     "lat": 30.3912943,
#                     "lng": -97.7154485
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.3924758802915,
#                         "lng": -97.7140246197085
#                     },
#                     "southwest": {
#                         "lat": 30.3897779197085,
#                         "lng": -97.7167225802915
#                     }
#                 }
#             },
#             "place_id": "Ei0yMzQwIFcgQnJha2VyIExuIFN0ZSBCLCBBdXN0aW4sIFRYIDc4NzU4LCBVU0EiIRofChYKFAoSCd0yHu_1y0SGEUWp6ps5Ai6VEgVTdGUgQg",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.3912943
# -97.7154485
# 8 Flying Man Brewing Company 2400 Patterson Industrial
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "2400",
#                     "short_name": "2400",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Patterson Industrial Drive",
#                     "short_name": "Patterson Industrial Dr",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Pflugerville",
#                     "short_name": "Pflugerville",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78660",
#                     "short_name": "78660",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "8312",
#                     "short_name": "8312",
#                     "types": [
#                         "postal_code_suffix"
#                     ]
#                 }
#             ],
#             "formatted_address": "2400 Patterson Industrial Dr, Pflugerville, TX 78660, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.402198,
#                         "lng": -97.62820529999999
#                     },
#                     "southwest": {
#                         "lat": 30.4019078,
#                         "lng": -97.6285795
#                     }
#                 },
#                 "location": {
#                     "lat": 30.4020944,
#                     "lng": -97.6284098
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4034018802915,
#                         "lng": -97.6270434197085
#                     },
#                     "southwest": {
#                         "lat": 30.4007039197085,
#                         "lng": -97.6297413802915
#                     }
#                 }
#             },
#             "place_id": "ChIJO0_T70vPRIYRBgRSqrcvulM",
#             "types": [
#                 "premise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.4020944
# -97.6284098
# 9 Hi Sign Brewing 1201 Old Bastrop Hwy Bldg A
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Bldg A",
#                     "short_name": "Bldg A",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "1201",
#                     "short_name": "1201",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Bastrop Highway",
#                     "short_name": "Bastrop Hwy",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78742",
#                     "short_name": "78742",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "1201 Bastrop Hwy Bldg A, Austin, TX 78742, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2271576,
#                         "lng": -97.6798387
#                     },
#                     "southwest": {
#                         "lat": 30.2261715,
#                         "lng": -97.68080859999999
#                     }
#                 },
#                 "location": {
#                     "lat": 30.2266459,
#                     "lng": -97.6803126
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2280135302915,
#                         "lng": -97.6789746697085
#                     },
#                     "southwest": {
#                         "lat": 30.2253155697085,
#                         "lng": -97.6816726302915
#                     }
#                 }
#             },
#             "place_id": "Ei4xMjAxIEJhc3Ryb3AgSHd5IEJsZGcgQSwgQXVzdGluLCBUWCA3ODc0MiwgVVNBIiIaIAoWChQKEgmRSmY-ubZEhhEwNLsDCI3nKxIGQmxkZyBB",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2266459
# -97.6803126
# 10 Hops & Grain Brewing 507 Calles St Ste 101
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "101",
#                     "short_name": "101",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "507",
#                     "short_name": "507",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Calles Street",
#                     "short_name": "Calles St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Holly",
#                     "short_name": "Holly",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78702",
#                     "short_name": "78702",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "507 Calles St #101, Austin, TX 78702, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2586802,
#                         "lng": -97.71126609999999
#                     },
#                     "southwest": {
#                         "lat": 30.2581513,
#                         "lng": -97.7124058
#                     }
#                 },
#                 "location": {
#                     "lat": 30.2584481,
#                     "lng": -97.71188509999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2597647302915,
#                         "lng": -97.7104869697085
#                     },
#                     "southwest": {
#                         "lat": 30.2570667697085,
#                         "lng": -97.7131849302915
#                     }
#                 }
#             },
#             "place_id": "Eik1MDcgQ2FsbGVzIFN0ICMxMDEsIEF1c3RpbiwgVFggNzg3MDIsIFVTQSIfGh0KFgoUChIJZdNPTcy1RIYR9dXdOGLSgOMSAzEwMQ",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2584481
# -97.71188509999999
# 12 Infamous Brewing 4602 Weletka Dr
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "4602",
#                     "short_name": "4602",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Weletka Drive",
#                     "short_name": "Weletka Dr",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis Landing",
#                     "short_name": "Travis Landing",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78734",
#                     "short_name": "78734",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "1830",
#                     "short_name": "1830",
#                     "types": [
#                         "postal_code_suffix"
#                     ]
#                 }
#             ],
#             "formatted_address": "4602 Weletka Dr, Austin, TX 78734, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.4069402,
#                         "lng": -97.9257945
#                     },
#                     "southwest": {
#                         "lat": 30.4067271,
#                         "lng": -97.9260734
#                     }
#                 },
#                 "location": {
#                     "lat": 30.4068376,
#                     "lng": -97.925942
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4081826302915,
#                         "lng": -97.9245849697085
#                     },
#                     "southwest": {
#                         "lat": 30.4054846697085,
#                         "lng": -97.92728293029151
#                     }
#                 }
#             },
#             "place_id": "ChIJcX8uGOYwW4YRF1osbcy48j8",
#             "types": [
#                 "premise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.4068376
# -97.925942
# 13 Last Stand Brewing Company 12345 Pauls Valley Rd
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "12345",
#                     "short_name": "12345",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Pauls Valley Road",
#                     "short_name": "Pauls Valley Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Hays County",
#                     "short_name": "Hays County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78737",
#                     "short_name": "78737",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "9633",
#                     "short_name": "9633",
#                     "types": [
#                         "postal_code_suffix"
#                     ]
#                 }
#             ],
#             "formatted_address": "12345 Pauls Valley Rd, Austin, TX 78737, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2358876,
#                     "lng": -98.0105991
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2372365802915,
#                         "lng": -98.0092501197085
#                     },
#                     "southwest": {
#                         "lat": 30.2345386197085,
#                         "lng": -98.0119480802915
#                     }
#                 }
#             },
#             "place_id": "ChIJKZm1nv1GW4YRXfXgGPwHTUs",
#             "plus_code": {
#                 "compound_code": "6XPQ+9Q Austin, TX, USA",
#                 "global_code": "86236XPQ+9Q"
#             },
#             "types": [
#                 "street_address"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2358876
# -98.0105991
# 14 Orf Brewing 4700 Burleson Rd Ste F
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ste F",
#                     "short_name": "Ste F",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "4700",
#                     "short_name": "4700",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Burleson Road",
#                     "short_name": "Burleson Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Southeast Austin",
#                     "short_name": "Southeast Austin",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78744",
#                     "short_name": "78744",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "4700 Burleson Rd Ste F, Austin, TX 78744, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2129385,
#                     "lng": -97.7307144
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2142874802915,
#                         "lng": -97.72936541970849
#                     },
#                     "southwest": {
#                         "lat": 30.2115895197085,
#                         "lng": -97.73206338029149
#                     }
#                 }
#             },
#             "place_id": "Ei00NzAwIEJ1cmxlc29uIFJkIFN0ZSBGLCBBdXN0aW4sIFRYIDc4NzQ0LCBVU0EiIRofChYKFAoSCW8luFd3tESGEX0MUX3uyxpLEgVTdGUgRg",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2129385
# -97.7307144
# 16 Skull Mechanix Brewing 1005 East St Elmo Rd Bldg 2
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Bldg 2",
#                     "short_name": "Bldg 2",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "2",
#                     "short_name": "2",
#                     "types": [
#                         "premise"
#                     ]
#                 },
#                 {
#                     "long_name": "1005",
#                     "short_name": "1005",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "East Saint Elmo Road",
#                     "short_name": "E St Elmo Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "South Austin",
#                     "short_name": "South Austin",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78745",
#                     "short_name": "78745",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "2, 1005 E St Elmo Rd Bldg 2, Austin, TX 78745, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2139506,
#                         "lng": -97.75537399999999
#                     },
#                     "southwest": {
#                         "lat": 30.2136447,
#                         "lng": -97.7557467
#                     }
#                 },
#                 "location": {
#                     "lat": 30.2138023,
#                     "lng": -97.7555488
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2151466302915,
#                         "lng": -97.75421136970849
#                     },
#                     "southwest": {
#                         "lat": 30.2124486697085,
#                         "lng": -97.75690933029149
#                     }
#                 }
#             },
#             "place_id": "EjIyLCAxMDA1IEUgU3QgRWxtbyBSZCBCbGRnIDIsIEF1c3RpbiwgVFggNzg3NDUsIFVTQSIiGiAKFgoUChIJo2laoZu0RIYR9vI8x5idTdsSBkJsZGcgMg",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2138023
# -97.7555488
# 17 South Austin Brewery 5701 W Slaughter Ln Bldg A130
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Bldg A130",
#                     "short_name": "Bldg A130",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "5701",
#                     "short_name": "5701",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "West Slaughter Lane",
#                     "short_name": "W Slaughter Ln",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78749",
#                     "short_name": "78749",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "5701 W Slaughter Ln Bldg A130, Austin, TX 78749, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2006752,
#                         "lng": -97.86896019999999
#                     },
#                     "southwest": {
#                         "lat": 30.2004804,
#                         "lng": -97.86946569999999
#                     }
#                 },
#                 "location": {
#                     "lat": 30.20057409999999,
#                     "lng": -97.8691415
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2019267802915,
#                         "lng": -97.86786396970848
#                     },
#                     "southwest": {
#                         "lat": 30.1992288197085,
#                         "lng": -97.87056193029149
#                     }
#                 }
#             },
#             "place_id": "EjQ1NzAxIFcgU2xhdWdodGVyIExuIEJsZGcgQTEzMCwgQXVzdGluLCBUWCA3ODc0OSwgVVNBIiUaIwoWChQKEgl9Bph2_0tbhhFtYb6XtbAfFRIJQmxkZyBBMTMw",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.20057409999999
# -97.8691415
# 18 Southern Heights Brewing Co LLC 6014 Techni Center Dr Ste 2-101
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ste 2-101",
#                     "short_name": "Ste 2-101",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "6014",
#                     "short_name": "6014",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Techni Center Drive",
#                     "short_name": "Techni Center Dr",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "MLK-183",
#                     "short_name": "MLK-183",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78721",
#                     "short_name": "78721",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "6014 Techni Center Dr Ste 2-101, Austin, TX 78721, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2771818,
#                         "lng": -97.6691481
#                     },
#                     "southwest": {
#                         "lat": 30.2765483,
#                         "lng": -97.66973899999999
#                     }
#                 },
#                 "location": {
#                     "lat": 30.2767076,
#                     "lng": -97.66947789999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2782140302915,
#                         "lng": -97.6680945697085
#                     },
#                     "southwest": {
#                         "lat": 30.2755160697085,
#                         "lng": -97.67079253029151
#                     }
#                 }
#             },
#             "place_id": "EjY2MDE0IFRlY2huaSBDZW50ZXIgRHIgU3RlIDItMTAxLCBBdXN0aW4sIFRYIDc4NzIxLCBVU0EiJRojChYKFAoSCQHSkOZGtkSGEWGXEp2oxBTOEglTdGUgMi0xMDE",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2767076
# -97.66947789999999
# 19 Strange Land Brewery 5904 Bee Cave Road
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "5904",
#                     "short_name": "5904",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Bee Cave Road",
#                     "short_name": "Bee Cave Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Westlake Medical Center",
#                     "short_name": "Westlake Medical Center",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "West Lake Hills",
#                     "short_name": "West Lake Hills",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78746",
#                     "short_name": "78746",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "5904 Bee Cave Rd, West Lake Hills, TX 78746, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 30.29625489999999,
#                     "lng": -97.82682
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.29760388029149,
#                         "lng": -97.8254710197085
#                     },
#                     "southwest": {
#                         "lat": 30.29490591970849,
#                         "lng": -97.82816898029151
#                     }
#                 }
#             },
#             "place_id": "ChIJPVM6pH81W4YRvTq1Lrnaf58",
#             "plus_code": {
#                 "compound_code": "75WF+G7 West Lake Hills, TX, USA",
#                 "global_code": "862475WF+G7"
#             },
#             "types": [
#                 "street_address"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.29625489999999
# -97.82682
# 23 Blue Owl Brewing 2400 E Cesar Chavez St Ste 300
# ADDRESS SEARCH...{
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "300",
#                     "short_name": "300",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "2400",
#                     "short_name": "2400",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "East Cesar Chavez Street",
#                     "short_name": "E Cesar Chavez St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Holly",
#                     "short_name": "Holly",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78702",
#                     "short_name": "78702",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "2400 E Cesar Chavez St #300, Austin, TX 78702, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.2554519,
#                         "lng": -97.7165409
#                     },
#                     "southwest": {
#                         "lat": 30.2543682,
#                         "lng": -97.7185246
#                     }
#                 },
#                 "location": {
#                     "lat": 30.2549674,
#                     "lng": -97.71773929999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.2562590302915,
#                         "lng": -97.7161837697085
#                     },
#                     "southwest": {
#                         "lat": 30.2535610697085,
#                         "lng": -97.7188817302915
#                     }
#                 }
#             },
#             "place_id": "EjIyNDAwIEUgQ2VzYXIgQ2hhdmV6IFN0ICMzMDAsIEF1c3RpbiwgVFggNzg3MDIsIFVTQSIfGh0KFgoUChIJOcjI1sq1RIYRGsNdcCAhFbwSAzMwMA",
#             "types": [
#                 "subpremise"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.2549674
# -97.71773929999999
# 24 Frontyard Brewing 1607 Cuernavaca Dr North Unit #202
# ADDRESS SEARCH...{
#     "error_message": "You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account",
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# CITY SEARCH...24Frontyard BrewingFrontyard Brewing,Austin,Texas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Suite 202",
#                     "short_name": "Suite 202",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "1607",
#                     "short_name": "1607",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Cuernavaca Drive North",
#                     "short_name": "Cuernavaca Dr N",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin Lake Estates",
#                     "short_name": "Austin Lake Estates",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "78733",
#                     "short_name": "78733",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "1607 Cuernavaca Dr N Suite 202, Austin, TX 78733, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 30.33938109999999,
#                     "lng": -97.86335419999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.34073008029149,
#                         "lng": -97.8620052197085
#                     },
#                     "southwest": {
#                         "lat": 30.3380321197085,
#                         "lng": -97.8647031802915
#                     }
#                 }
#             },
#             "place_id": "ChIJb-p6Gi00W4YRElwv5rUKtVY",
#             "plus_code": {
#                 "compound_code": "84QP+QM Austin, TX, USA",
#                 "global_code": "862484QP+QM"
#             },
#             "types": [
#                 "establishment",
#                 "food",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# 30.33938109999999
# -97.86335419999999

# %%
breweries_bycity_df
# Out:
#                                   Name   Type  \
# 0                  Jester King Brewery  micro
# 1          Oasis Texas Brewing Company  micro
# 2                     (512) Brewing Co  micro
# 3          4th Tap Brewing Cooperative  micro
# 4               Adelbert's Brewery LLC  micro
# 5                        Celis Brewery  micro
# 6               Circle Brewing Company  micro
# 7        Draught House Pub and Brewery  micro
# 8           Flying Man Brewing Company  micro
# 9                      Hi Sign Brewing  micro
# 10                Hops & Grain Brewing  micro
# 11  Friends and Allies Brewing Company  micro
# 12                    Infamous Brewing  micro
# 13          Last Stand Brewing Company  micro
# 14                         Orf Brewing  micro
# 15                 Oskar Blues Brewery  micro
# 16              Skull Mechanix Brewing  micro
# 17                South Austin Brewery  micro
# 18     Southern Heights Brewing Co LLC  micro
# 19                Strange Land Brewery  micro
# 20           Thirsty Planet Brewing Co  micro
# 21               Uncle Billy's Brewery  micro
# 22                   Zilker Brewing Co  micro
# 23                    Blue Owl Brewing  micro
# 24                   Frontyard Brewing  micro
# 25            St. Elmo Brewing Company  micro
#
#                                Address       Phone    City  State         ZIP  \
# 0                    13187 Fitzhugh Rd  5125375100  Austin  Texas  78736-6510
# 1            6548 Comanche Trl Ste 301  5122849407  Austin  Texas  78732-1210
# 2                407 Radam Ln Ste F200  5129211545  Austin  Texas  78745-1197
# 3                    10615 Metric Blvd  5129089817  Austin  Texas  78758-4520
# 4              2314 Rutland Dr Ste 100  5126621462  Austin  Texas  78758-5273
# 5                    10001 Metic Blvd.  5125242377  Austin  Texas       78758
# 6               2340 W Braker Ln Ste B  5128147599  Austin  Texas  78758-4542
# 7            4112 Medical Pkwy Ste 100  5124526258  Austin  Texas  78756-3715
# 8            2400 Patterson Industrial  5129104099  Austin  Texas       78660
# 9          1201 Old Bastrop Hwy Bldg A  5123825264  Austin  Texas  78742-2600
# 10               507 Calles St Ste 101  5129142467  Austin  Texas  78702-3954
# 11           979 Springdale Rd Ste 124              Austin  Texas  78702-3753
# 12                     4602 Weletka Dr  5124878786  Austin  Texas  78734-1829
# 13               12345 Pauls Valley Rd  5123733629  Austin  Texas  78737-9615
# 14              4700 Burleson Rd Ste F  5124285217  Austin  Texas  78744-1230
# 15             10420 Metric Blvd # 150  5122437054  Austin  Texas  78758-4939
# 16         1005 East St Elmo Rd Bldg 2  7373001002  Austin  Texas       78745
# 17       5701 W Slaughter Ln Bldg A130  5123542337  Austin  Texas  78749-6532
# 18     6014 Techni Center Dr Ste 2-101  5126506901  Austin  Texas  78721-2349
# 19                  5904 Bee Cave Road  5122762295  Austin  Texas       78746
# 20                 8201 S Congress Ave  5128260948  Austin  Texas  78745-7305
# 21              1530 Barton Springs Rd  5124760100  Austin  Texas  78704-1013
# 22                       1701 E 6th St  5127654946  Austin  Texas  78702-2701
# 23      2400 E Cesar Chavez St Ste 300  5125931262  Austin  Texas  78702-4638
# 24  1607 Cuernavaca Dr North Unit #202  8503227498  Austin  Texas       78733
# 25                 440 E Saint Elmo Rd  7373001965  Austin  Texas  78745-1281
#
#           Country                                Website        Lat        Lng
# 0   United States       http://www.jesterkingbrewery.com  30.254726 -98.082469
# 1   United States                   http://www.otxbc.com  30.043267 -98.151206
# 2   United States              http://www.512brewing.com  30.222487 -97.770024
# 3   United States                                         30.385202 -97.711891
# 4   United States           http://www.adelbertsbeer.com  30.382629 -97.720159
# 5   United States              http://www.celisbeers.com  30.379808 -97.715958
# 6   United States           http://www.circlebrewing.com  30.391294 -97.715448
# 7   United States            http://www.draughthouse.com  30.311071 -97.742861
# 8   United States        http://www.flyingmanbrewing.com  30.402094 -97.628410
# 9   United States           http://www.hisignbrewing.com  30.226646 -97.680313
# 10  United States            http://www.hopsandgrain.com  30.258448 -97.711885
# 11  United States       http://www.friendsandallies.beer  30.262862 -97.696185
# 12  United States         http://www.infamousbrewing.com  30.406838 -97.925942
# 13  United States        http://www.laststandbrewing.com  30.235888 -98.010599
# 14  United States              http://www.orfbrewing.com  30.212938 -97.730714
# 15  United States                                         30.383929 -97.714702
# 16  United States           http://www.skullmechanix.com  30.213802 -97.755549
# 17  United States      http://www.southaustinbrewery.com  30.200574 -97.869141
# 18  United States  http://www.southernheightsbrewing.com  30.276708 -97.669478
# 19  United States      http://www.strangelandbrewery.com  30.296255 -97.826820
# 20  United States           http://www.thirstyplanet.net  30.252166 -97.748714
# 21  United States             http://www.unclebillys.com  30.262109 -97.761269
# 22  United States              http://www.zilkerbeer.com  30.262151 -97.724575
# 23  United States          http://www.blueowlbrewing.com  30.254967 -97.717739
# 24  United States        http://www.frontyardbrewing.com  30.339381 -97.863354
# 25  United States           http://www.stelmobrewing.com  30.217432 -97.761175

# %%
# Reset variables
breweries = []
brewery_locations = []
brewery_info = []

for index, row in breweries_bycity_df.iterrows():
    #print(row)
    breweries.append({
            "Name": row['Name'], 
            "City": row['City'], 
            "State": row['State'],
            "Location": [row['Lat'], row['Lng']]
            })
#print(breweries)

for brewery in breweries:
    #print(brewery)
    brewery_locations.append(brewery['Location'])
#print(brewery_locations)

info_box_template = """
<dl>
<dt>Brewery</dt><dd>{Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{State}</dd>
</dl>
"""
brewery_info = [info_box_template.format(**brewery) for brewery in breweries]

# %%
fig2 = gmaps.figure(map_type='TERRAIN')
lat_avg = breweries_bycity_df['Lat'].mean()
lng_avg = breweries_bycity_df['Lng'].mean()
city_coordinates = (lat_avg, lng_avg)
fig2 = gmaps.figure(center=city_coordinates, zoom_level=10)
marker_layer2 = gmaps.marker_layer(brewery_locations, info_box_content=brewery_info)
fig2.add_layer(marker_layer2)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
w1 = widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
display(w1)

# %%
print(w1.value)
w1.close()
