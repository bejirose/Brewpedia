# %%
# This Jupyter notebook accesses Breweries data from https://googles.p.rapidapi.com/breweries

import ipywidgets as widgets
import pandas as pd
import numpy as np
import requests
import json
import gmaps
from api_keys import rapidapi_key
from api_keys import g_key
gmaps.configure(api_key=g_key)

count = 0
name = []
type = []
address = []
phone = []
city = []
state = []
zip = []
country = []
website =[]
lat = []
lng = []

url1 = "https://googles.p.rapidapi.com/breweries"

headers = {
    'x-rapidapi-host': "googles.p.rapidapi.com",
    'x-rapidapi-key': rapidapi_key
    }

response = requests.request("GET", url1, headers=headers)
#print(response.text)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
for block in response_json:
    #print(block)
    count +=1
    name.append(block['name'])
    type.append(block['brewery_type'])
    address.append(block['street'])
    phone.append(block['phone'])
    city.append(block['city'])
    state.append(block['state'])
    zip.append(block['postal_code'])
    country.append(block['country'])
    website.append(block['website_url'])
    lat.append(block['latitude'])
    lng.append(block['longitude'])
# Out:
# [
#     {
#         "brewery_type": "micro",
#         "city": "Birmingham",
#         "country": "United States",
#         "id": 2,
#         "latitude": "33.524521",
#         "longitude": "-86.774322",
#         "name": "Avondale Brewing Co",
#         "phone": "2057775456",
#         "postal_code": "35222-1932",
#         "state": "Alabama",
#         "street": "201 41st St S",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:19:57.825Z",
#         "website_url": "http://www.avondalebrewing.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Birmingham",
#         "country": "United States",
#         "id": 44,
#         "latitude": "33.5128492349817",
#         "longitude": "-86.7914000624146",
#         "name": "Trim Tab Brewing",
#         "phone": "2057030536",
#         "postal_code": "35233-3401",
#         "state": "Alabama",
#         "street": "2721 5th Ave S",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:20:31.423Z",
#         "website_url": "http://www.trimtabbrewing.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Huntsville",
#         "country": "United States",
#         "id": 46,
#         "latitude": "34.7277523",
#         "longitude": "-86.5932014",
#         "name": "Yellowhammer Brewery",
#         "phone": "2569755950",
#         "postal_code": "35805-3046",
#         "state": "Alabama",
#         "street": "2600 Clinton Ave W",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:20:33.102Z",
#         "website_url": "http://www.yellowhammerbrewery.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Wasilla",
#         "country": "United States",
#         "id": 55,
#         "latitude": "61.5752695",
#         "longitude": "-149.4127103",
#         "name": "Bearpaw River Brewing Co",
#         "phone": "",
#         "postal_code": "99654-7679",
#         "state": "Alaska",
#         "street": "4605 E Palmer Wasilla Hwy",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:20:40.743Z",
#         "website_url": "http://bearpawriverbrewing.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Anchorage",
#         "country": "United States",
#         "id": 76,
#         "latitude": "61.1384893547315",
#         "longitude": "-149.879076042937",
#         "name": "King Street Brewing Co",
#         "phone": "9073365464",
#         "postal_code": "99515",
#         "state": "Alaska",
#         "street": "9050 King Street",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:20:57.179Z",
#         "website_url": "http://www.kingstreetbrewing.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Tucson",
#         "country": "United States",
#         "id": 94,
#         "latitude": "32.2467372722906",
#         "longitude": "-110.992750525872",
#         "name": "1912 Brewing",
#         "phone": "5202564851",
#         "postal_code": "85745-1444",
#         "state": "Arizona",
#         "street": "2045 N Forbes Blvd Ste 105",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:11.302Z",
#         "website_url": "http://www.1912brewing.com"
#     },
#     {
#         "brewery_type": "contract",
#         "city": "Scottsdale",
#         "country": "United States",
#         "id": 98,
#         "latitude": "33.4972615652174",
#         "longitude": "-111.924474347826",
#         "name": "Bad Water Brewing",
#         "phone": "5207459175",
#         "postal_code": "85251-3914",
#         "state": "Arizona",
#         "street": "4216 N Brown Ave",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:15.169Z",
#         "website_url": "http://www.badwaterbrewing.com"
#     },
#     {
#         "brewery_type": "brewpub",
#         "city": "Chandler",
#         "country": "United States",
#         "id": 104,
#         "latitude": "33.3053455",
#         "longitude": "-111.911126",
#         "name": "BJs Restaurant & Brewery - Chandler",
#         "phone": "4809170631",
#         "postal_code": "85226-5175",
#         "state": "Arizona",
#         "street": "3155 W Chandler Blvd",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:21.165Z",
#         "website_url": "http://www.bjsrestaurants.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Tucson",
#         "country": "United States",
#         "id": 107,
#         "latitude": "32.201608314954",
#         "longitude": "-110.821778571134",
#         "name": "BlackRock Brewers",
#         "phone": "5202073203",
#         "postal_code": "85710-6767",
#         "state": "Arizona",
#         "street": "1664 S Research Loop Ste 200",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:23.794Z",
#         "website_url": "http://www.brb.beer"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Tucson",
#         "country": "United States",
#         "id": 127,
#         "latitude": "32.2504946147872",
#         "longitude": "-111.005452051979",
#         "name": "Dragoon Brewing Co",
#         "phone": "5203293606",
#         "postal_code": "85745-1214",
#         "state": "Arizona",
#         "street": "1859 W Grant Rd Ste 111",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:40.563Z",
#         "website_url": "http://www.dragoonbrewing.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Williams",
#         "country": "United States",
#         "id": 141,
#         "latitude": "35.2500282",
#         "longitude": "-112.1892168",
#         "name": "Grand Canyon Brewing Company",
#         "phone": "8005132072",
#         "postal_code": "86046-2530",
#         "state": "Arizona",
#         "street": "233 W Route 66",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:21:53.397Z",
#         "website_url": "http://www.grandcanyonbrewingco.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Lake Havasu City",
#         "country": "United States",
#         "id": 163,
#         "latitude": "34.4689736300844",
#         "longitude": "-114.342433477881",
#         "name": "Mudshark Brewing Co",
#         "phone": "9284532981",
#         "postal_code": "86403-0966",
#         "state": "Arizona",
#         "street": "210 Swanson Ave",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:22:12.542Z",
#         "website_url": "http://www.mudsharkbrewingco.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Peoria",
#         "country": "United States",
#         "id": 182,
#         "latitude": "33.6687744976834",
#         "longitude": "-112.238054093359",
#         "name": "Richter Aleworks",
#         "phone": "6029086553",
#         "postal_code": "85382-7434",
#         "state": "Arizona",
#         "street": "8279 W Lake Pleasant Pkwy Ste 110",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:22:29.385Z",
#         "website_url": "http://www.richteraleworks.com"
#     },
#     {
#         "brewery_type": "regional",
#         "city": "Chandler",
#         "country": "United States",
#         "id": 187,
#         "latitude": "33.3032436",
#         "longitude": "-111.8423459",
#         "name": "SanTan Brewing Co",
#         "phone": "4809178700",
#         "postal_code": "85225-7862",
#         "state": "Arizona",
#         "street": "8 S San Marcos Pl",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:22:33.482Z",
#         "website_url": "http://www.santanbrewing.com"
#     },
#     {
#         "brewery_type": "brewpub",
#         "city": "Surprise",
#         "country": "United States",
#         "id": 198,
#         "latitude": "33.63822125",
#         "longitude": "-112.357813820157",
#         "name": "State 48 Brewery",
#         "phone": "6235841095",
#         "postal_code": "85374-3873",
#         "state": "Arizona",
#         "street": "13823 W Bell Rd",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:22:41.468Z",
#         "website_url": ""
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Phoenix",
#         "country": "United States",
#         "id": 219,
#         "latitude": "33.516633",
#         "longitude": "-112.0301125",
#         "name": "Wren House Brewing Company",
#         "phone": "6022449184",
#         "postal_code": "85008-2713",
#         "state": "Arizona",
#         "street": "2125 N 24th St",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:22:59.255Z",
#         "website_url": "http://www.wrenhousebrewing.com"
#     },
#     {
#         "brewery_type": "brewpub",
#         "city": "Paragould",
#         "country": "United States",
#         "id": 225,
#         "latitude": "36.0316358142169",
#         "longitude": "-90.5204797204622",
#         "name": "Brick Oven Pizza Co / Brick & Forge Brewing",
#         "phone": "8702364200",
#         "postal_code": "72450-6122",
#         "state": "Arkansas",
#         "street": "2410 Linwood Dr",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:23:05.438Z",
#         "website_url": "http://www.brickovenpizzacompany.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "North Little Rock",
#         "country": "United States",
#         "id": 235,
#         "latitude": "34.7594277548278",
#         "longitude": "-92.2726892120821",
#         "name": "Diamond Bear Brewing Co",
#         "phone": "5017082739",
#         "postal_code": "72114-5381",
#         "state": "Arkansas",
#         "street": "600 N Broadway St",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:23:14.931Z",
#         "website_url": "http://www.diamondbear.com"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Little Rock",
#         "country": "United States",
#         "id": 247,
#         "latitude": "34.742845",
#         "longitude": "-92.260019",
#         "name": "Lost Forty Brewing",
#         "phone": "5013197275",
#         "postal_code": "72202",
#         "state": "Arkansas",
#         "street": "501 Byrd St",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:23:24.018Z",
#         "website_url": "http://www.lost40brewing.com/"
#     },
#     {
#         "brewery_type": "micro",
#         "city": "Mountain Home",
#         "country": "United States",
#         "id": 253,
#         "latitude": "36.3326432",
#         "longitude": "-92.3599724",
#         "name": "Rapp's Barren Brewing Company",
#         "phone": "8704247288",
#         "postal_code": "72653-5050",
#         "state": "Arkansas",
#         "street": "1343 E 9th St",
#         "tag_list": [],
#         "updated_at": "2018-08-23T23:23:29.428Z",
#         "website_url": "http://www.rappsbarrenbrewing.com"
#     }
# ]

# %%
# create a data frame from cities and all the response parameters
breweries_dict = {
    "Name": name,
    "Type": type,
    "Address": address,
    "Phone": phone,
    "City": city,
    "State": state,
    "ZIP": zip,
    "Country": country,
    "Website": website,
    "Lat": lat,
    "Lng": lng
}
breweries_df = pd.DataFrame(breweries_dict)
breweries_df['Lat'] = pd.to_numeric(breweries_df['Lat'], errors='coerce')
breweries_df['Lng'] = pd.to_numeric(breweries_df['Lng'], errors='coerce')
breweries_df.head()
# Out:
#                        Name   Type                    Address       Phone  \
# 0       Avondale Brewing Co  micro              201 41st St S  2057775456
# 1          Trim Tab Brewing  micro             2721 5th Ave S  2057030536
# 2      Yellowhammer Brewery  micro         2600 Clinton Ave W  2569755950
# 3  Bearpaw River Brewing Co  micro  4605 E Palmer Wasilla Hwy
# 4    King Street Brewing Co  micro           9050 King Street  9073365464
#
#          City    State         ZIP        Country  \
# 0  Birmingham  Alabama  35222-1932  United States
# 1  Birmingham  Alabama  35233-3401  United States
# 2  Huntsville  Alabama  35805-3046  United States
# 3     Wasilla   Alaska  99654-7679  United States
# 4   Anchorage   Alaska       99515  United States
#
#                               Website        Lat         Lng
# 0      http://www.avondalebrewing.com  33.524521  -86.774322
# 1       http://www.trimtabbrewing.com  33.512849  -86.791400
# 2  http://www.yellowhammerbrewery.com  34.727752  -86.593201
# 3      http://bearpawriverbrewing.com  61.575269 -149.412710
# 4    http://www.kingstreetbrewing.com  61.138489 -149.879076

# %%
locations = breweries_df[['Lat', 'Lng']]
breweries_layer = gmaps.symbol_layer(
    locations, fill_color='red', stroke_color='red', scale=3
)
fig = gmaps.figure(map_type='TERRAIN')
phoenix_coordinates = (33.439902, -112.070125)
fig = gmaps.figure(center=phoenix_coordinates, zoom_level=4)
fig.add_layer(breweries_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
breweries = []
brewery_locations = []
for index, row in breweries_df.iterrows():
    #print(row)
    breweries.append({
            "Name": row['Name'], 
            "City": row['City'], 
            "State": row['State'],
            "Location": [row['Lat'], row['Lng']]
            })
#print(breweries)

for brewery in breweries:
    print(brewery)
    brewery_locations.append(brewery['Location'])

#print(brewery_locations)
info_box_template = """
<dl>
<dt>Brewery</dt><dd>{Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{State}</dd>
</dl>
"""
brewery_info = [info_box_template.format(**brewery) for brewery in breweries]
# Out:
# {'Name': 'Avondale Brewing Co', 'City': 'Birmingham', 'State': 'Alabama', 'Location': [33.524521, -86.774322]}
# {'Name': 'Trim Tab Brewing', 'City': 'Birmingham', 'State': 'Alabama', 'Location': [33.5128492349817, -86.7914000624146]}
# {'Name': 'Yellowhammer Brewery', 'City': 'Huntsville', 'State': 'Alabama', 'Location': [34.7277523, -86.59320140000001]}
# {'Name': 'Bearpaw River Brewing Co', 'City': 'Wasilla', 'State': 'Alaska', 'Location': [61.5752695, -149.41271030000001]}
# {'Name': 'King Street Brewing Co', 'City': 'Anchorage', 'State': 'Alaska', 'Location': [61.138489354731504, -149.879076042937]}
# {'Name': '1912 Brewing', 'City': 'Tucson', 'State': 'Arizona', 'Location': [32.2467372722906, -110.992750525872]}
# {'Name': 'Bad Water Brewing', 'City': 'Scottsdale', 'State': 'Arizona', 'Location': [33.4972615652174, -111.924474347826]}
# {'Name': 'BJs Restaurant & Brewery - Chandler', 'City': 'Chandler', 'State': 'Arizona', 'Location': [33.3053455, -111.911126]}
# {'Name': 'BlackRock Brewers', 'City': 'Tucson', 'State': 'Arizona', 'Location': [32.201608314954, -110.82177857113399]}
# {'Name': 'Dragoon Brewing Co', 'City': 'Tucson', 'State': 'Arizona', 'Location': [32.2504946147872, -111.005452051979]}
# {'Name': 'Grand Canyon Brewing Company', 'City': 'Williams', 'State': 'Arizona', 'Location': [35.2500282, -112.18921680000001]}
# {'Name': 'Mudshark Brewing Co', 'City': 'Lake Havasu City', 'State': 'Arizona', 'Location': [34.4689736300844, -114.34243347788099]}
# {'Name': 'Richter Aleworks', 'City': 'Peoria', 'State': 'Arizona', 'Location': [33.668774497683394, -112.238054093359]}
# {'Name': 'SanTan Brewing Co', 'City': 'Chandler', 'State': 'Arizona', 'Location': [33.3032436, -111.8423459]}
# {'Name': 'State 48 Brewery', 'City': 'Surprise', 'State': 'Arizona', 'Location': [33.63822125, -112.35781382015699]}
# {'Name': 'Wren House Brewing Company', 'City': 'Phoenix', 'State': 'Arizona', 'Location': [33.516633, -112.0301125]}
# {'Name': 'Brick Oven Pizza Co / Brick & Forge Brewing', 'City': 'Paragould', 'State': 'Arkansas', 'Location': [36.0316358142169, -90.5204797204622]}
# {'Name': 'Diamond Bear Brewing Co', 'City': 'North Little Rock', 'State': 'Arkansas', 'Location': [34.7594277548278, -92.2726892120821]}
# {'Name': 'Lost Forty Brewing', 'City': 'Little Rock', 'State': 'Arkansas', 'Location': [34.742845, -92.260019]}
# {'Name': "Rapp's Barren Brewing Company", 'City': 'Mountain Home', 'State': 'Arkansas', 'Location': [36.3326432, -92.3599724]}

# %%
fig = gmaps.figure(map_type='TERRAIN')
phoenix_coordinates = (33.439902, -112.070125)
fig = gmaps.figure(center=phoenix_coordinates, zoom_level=6)
marker_layer = gmaps.marker_layer(brewery_locations, info_box_content=brewery_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
